# %%
import pandas as pd
from sqlalchemy import create_engine
import datetime as dt
import numpy as np

# %%
#reading csv files into python
Artist_File_Path='Resources/artistDf.csv'
Billboard_File_Path='Resources/billboardHot100_1999-2019_sample.csv'
Grammy_File_Path='Resources/grammySongs_1999-2019.csv'

Adf=pd.read_csv(Artist_File_Path)
Bdf = pd.read_csv(Billboard_File_Path)
Gdf=pd.read_csv(Grammy_File_Path)

# %%
def login():
    pw=input("Please enter your password for PGAdmin: ")
    return pw

# %%
#eliminate extra columns
Adf=Adf[['Artist','Genres','NumAlbums','Gender']].copy()
Bdf = Bdf[['Artists', 'Name', 'Peak.position', 'Weeks.on.chart','Week','Genre']].copy()
Gdf=Gdf[['Artist','GrammyAward','GrammyYear','Name', 'Genre']].copy()

# %%
#get rid of all na columns
Adf=Adf.dropna()
Bdf=Bdf.dropna()
Gdf=Gdf.dropna()
#changed all strings to lower case
Gdf = Gdf.astype(str).apply(lambda x: x.str.lower())
Adf = Adf.astype(str).apply(lambda x: x.str.lower())
Bdf = Bdf.astype(str).apply(lambda x: x.str.lower())

# %% [markdown]
# ### Artist dataframe

# %%
# Rename the column headers
Adf = Adf.rename(columns={'Artist':'artist', 
'Genres': 'genre',
'NumAlbums': 'num_albums',
'Gender': 'gender',
'Group.Solo': 'group_solo'})

# Clean the data by dropping duplicates and setting the index
Adf.drop_duplicates('artist', inplace=True)
Adf.set_index('artist', inplace=True)
Adf.head()
# Out:
#                                                             genre num_albums  \
# artist
# ed sheeran                                             pop,uk pop          8
# justin bieber            canadian pop,dance pop,pop,post-teen pop         10
# jonas brothers               boy band,dance pop,pop,post-teen pop         10
# drake           canadian hip hop,canadian pop,hip hop,pop rap,...         11
# chris brown                         dance pop,pop,pop rap,r&b,rap          6
#
#                gender
# artist
# ed sheeran          m
# justin bieber       m
# jonas brothers      m
# drake               m
# chris brown         m

# %%
#Checking for null values 
Adf.isnull().sum()
# Out:
# genre         0
# num_albums    0
# gender        0
# dtype: int64

# %% [markdown]
# ### Billboard dataframe

# %%
Bdf = Bdf.rename(columns={'Artists':'artist',
                          'Name': 'name_of_song',
                          'Peak.position': 'peak_position',
                          'Weeks.on.chart': 'weeks_on_chart',
                          'Week': 'year',
                          'Genre': 'genre'})
Bdf
# Out:
#                           artist             name_of_song peak_position  \
# 0                       lil nas,            old town road           1.0
# 2                  billie eilish                  bad guy           2.0
# 3                         khalid                     talk           3.0
# 4      ed sheeran, justin bieber             i don't care           2.0
# 5                 jonas brothers                   sucker           1.0
# ...                          ...                      ...           ...
# 24995                schoolboy q                   studio          75.0
# 24996               dustin lynch            where it's at          76.0
# 24997             craig campbell  keep them kisses comin'          72.0
# 24998                      lorde             tennis court          71.0
# 24999                 jhene aiko                the worst          43.0
#
#       weeks_on_chart        year  \
# 0                7.0  2019-07-06
# 2               13.0  2019-07-06
# 3               20.0  2019-07-06
# 4                7.0  2019-07-06
# 5               17.0  2019-07-06
# ...              ...         ...
# 24995            3.0  2014-07-04
# 24996            7.0  2014-07-04
# 24997            8.0  2014-07-04
# 24998           13.0  2014-07-04
# 24999           20.0  2014-07-04
#
#                                                    genre
# 0      country,atlanta,alternative country,hip-hop,tr...
# 2      hip-hop,dark pop,house,trap,memes,alternative ...
# 3                                          synth-pop,pop
# 4                          canada,uk,dance,dance-pop,pop
# 5         alternative pop,boy band,teen pop,pop-rock,pop
# ...                                                  ...
# 24995                                     west coast,rap
# 24996                                       rock,country
# 24997                                                pop
# 24998  alternative pop,alternative,downtempo,new zeal...
# 24999                                               r&;b
#
# [22863 rows x 6 columns]

# %%
#Change year column to datetime
Bdf['year']= pd.to_datetime(Bdf['year'])
#Retain only the year from datetime
Bdf['year'] = Bdf['year'].dt.year
Bdf
# Out:
#                           artist             name_of_song peak_position  \
# 0                       lil nas,            old town road           1.0
# 2                  billie eilish                  bad guy           2.0
# 3                         khalid                     talk           3.0
# 4      ed sheeran, justin bieber             i don't care           2.0
# 5                 jonas brothers                   sucker           1.0
# ...                          ...                      ...           ...
# 24995                schoolboy q                   studio          75.0
# 24996               dustin lynch            where it's at          76.0
# 24997             craig campbell  keep them kisses comin'          72.0
# 24998                      lorde             tennis court          71.0
# 24999                 jhene aiko                the worst          43.0
#
#       weeks_on_chart  year                                              genre
# 0                7.0  2019  country,atlanta,alternative country,hip-hop,tr...
# 2               13.0  2019  hip-hop,dark pop,house,trap,memes,alternative ...
# 3               20.0  2019                                      synth-pop,pop
# 4                7.0  2019                      canada,uk,dance,dance-pop,pop
# 5               17.0  2019     alternative pop,boy band,teen pop,pop-rock,pop
# ...              ...   ...                                                ...
# 24995            3.0  2014                                     west coast,rap
# 24996            7.0  2014                                       rock,country
# 24997            8.0  2014                                                pop
# 24998           13.0  2014  alternative pop,alternative,downtempo,new zeal...
# 24999           20.0  2014                                               r&;b
#
# [22863 rows x 6 columns]

# %%
# Check if the 'artists_split' list is greater than 1. If it is, it means that more than one artist is listed for a song.
# Modify original Bdf dataframe with one name in artist colum   
Bdf = Bdf.drop('artist', axis=1).join(Bdf['artist'].str.split(',', expand=True).stack().reset_index(level=1, drop=True).rename('artist'))
Bdf
# Out:
#                   name_of_song peak_position weeks_on_chart  year  \
# 0                old town road           1.0            7.0  2019
# 0                old town road           1.0            7.0  2019
# 2                      bad guy           2.0           13.0  2019
# 3                         talk           3.0           20.0  2019
# 4                 i don't care           2.0            7.0  2019
# ...                        ...           ...            ...   ...
# 24995                   studio          75.0            3.0  2014
# 24996            where it's at          76.0            7.0  2014
# 24997  keep them kisses comin'          72.0            8.0  2014
# 24998             tennis court          71.0           13.0  2014
# 24999                the worst          43.0           20.0  2014
#
#                                                    genre          artist
# 0      country,atlanta,alternative country,hip-hop,tr...         lil nas
# 0      country,atlanta,alternative country,hip-hop,tr...
# 2      hip-hop,dark pop,house,trap,memes,alternative ...   billie eilish
# 3                                          synth-pop,pop          khalid
# 4                          canada,uk,dance,dance-pop,pop      ed sheeran
# ...                                                  ...             ...
# 24995                                     west coast,rap     schoolboy q
# 24996                                       rock,country    dustin lynch
# 24997                                                pop  craig campbell
# 24998  alternative pop,alternative,downtempo,new zeal...           lorde
# 24999                                               r&;b      jhene aiko
#
# [25553 rows x 6 columns]

# %%
Bdf.head(50)
# Out:
#                  name_of_song peak_position weeks_on_chart  year  \
# 0               old town road           1.0            7.0  2019
# 0               old town road           1.0            7.0  2019
# 2                     bad guy           2.0           13.0  2019
# 3                        talk           3.0           20.0  2019
# 4                i don't care           2.0            7.0  2019
# 4                i don't care           2.0            7.0  2019
# 5                      sucker           1.0           17.0  2019
# 6                        suge           7.0           13.0  2019
# 7          money in the grave           7.0            2.0  2019
# 8                 no guidance           9.0            3.0  2019
# 9                        wow.           2.0           27.0  2019
# 10                truth hurts          11.0            8.0  2019
# 11                  sunflower           1.0           36.0  2019
# 11                  sunflower           1.0           36.0  2019
# 12      you need to calm down           2.0            2.0  2019
# 13        if i can't have you           2.0            8.0  2019
# 14    dancing with a stranger           7.0           24.0  2019
# 14    dancing with a stranger           7.0           24.0  2019
# 16                 without me           1.0           38.0  2019
# 17              god's country          18.0           13.0  2019
# 18                    pop out          11.0           14.0  2019
# 20           sweet but psycho          10.0           28.0  2019
# 22                    7 rings           1.0           23.0  2019
# 23     hey look ma, i made it          24.0           11.0  2019
# 24                    happier           2.0           45.0  2019
# 24                    happier           2.0           45.0  2019
# 25                      rumor          25.0           16.0  2019
# 26          never really over          15.0            4.0  2019
# 27            whiskey glasses          17.0           17.0  2019
# 28                 the git up          29.0            3.0  2019
# 29                 the london          12.0            5.0  2019
# 29                 the london          12.0            5.0  2019
# 29                 the london          12.0            5.0  2019
# 30                        me!           2.0           10.0  2019
# 31                 high hopes           4.0           47.0  2019
# 32  beer never broke my heart          22.0            8.0  2019
# 33                     act up          26.0           17.0  2019
# 34                   eastside           9.0           50.0  2019
# 34                   eastside           9.0           50.0  2019
# 34                   eastside           9.0           50.0  2019
# 35               middle child           4.0           23.0  2019
# 36                  con calma          22.0           21.0  2019
# 36                  con calma          22.0           21.0  2019
# 37                 pure water          23.0           22.0  2019
# 37                 pure water          23.0           22.0  2019
# 38                   cross me          34.0            5.0  2019
# 39                  going bad           6.0           30.0  2019
# 40                     better           8.0           41.0  2019
# 41                    shallow           1.0           39.0  2019
# 41                    shallow           1.0           39.0  2019
#
#                                                 genre               artist
# 0   country,atlanta,alternative country,hip-hop,tr...              lil nas
# 0   country,atlanta,alternative country,hip-hop,tr...
# 2   hip-hop,dark pop,house,trap,memes,alternative ...        billie eilish
# 3                                       synth-pop,pop               khalid
# 4                       canada,uk,dance,dance-pop,pop           ed sheeran
# 4                       canada,uk,dance,dance-pop,pop        justin bieber
# 5      alternative pop,boy band,teen pop,pop-rock,pop       jonas brothers
# 6                                 trap,east coast,rap               dababy
# 7                   hip-hop,rap,basketball,nba,canada                drake
# 8    alternative r&;b,hip-hop,rap,pop,dmv,canada,r&;b          chris brown
# 9                              memes,hip-hop,trap,rap          post malone
# 10                                            pop,rap                lizzo
# 11      rap,disney,hip-hop,marvel,soundtrack,r&;b,pop          post malone
# 11      rap,disney,hip-hop,marvel,soundtrack,r&;b,pop             swae lee
# 12                               synth-pop,lgbtq+,pop         taylor swift
# 13                                canada,teen pop,pop         shawn mendes
# 14                                             uk,pop            sam smith
# 14                                             uk,pop              normani
# 16  synth-pop,r&;b,alternative pop,ballad,pop,alte...               halsey
# 17                                            country        blake shelton
# 18                                           trap,rap               polo g
# 20  dance-pop,dance,electronic pop,electro,r&;b,el...              ava max
# 22                                memes,trap,r&;b,pop        ariana grande
# 23  pop-rock,jazz fusion,alternative,alternative p...  panic! at the disco
# 24  adult alternative,producer,alternative dance,a...           marshmello
# 24  adult alternative,producer,alternative dance,a...             bastille
# 25                                            country            lee brice
# 26                          electro-pop,synth-pop,pop           katy perry
# 27                                            country        morgan wallen
# 28              atlanta,dance,rap,country rap,country         blanco brown
# 29                     hip-hop,east coast,atlanta,rap           young thug
# 29                     hip-hop,east coast,atlanta,rap              j. cole
# 29                     hip-hop,east coast,atlanta,rap         travis scott
# 30              dream-pop,bubblegum pop,dance-pop,pop         taylor swift
# 31  adult alternative,rock,power pop,pop-rock,alte...  panic! at the disco
# 32                                       rock,country           luke combs
# 33                              motown,east coast,rap           city girls
# 34                                           r&;b,pop         benny blanco
# 34                                           r&;b,pop               halsey
# 34                                           r&;b,pop               khalid
# 35                                trap,east coast,rap              j. cole
# 36  latin pop,dancehall,pop,reggaeton,en espa\xc3\...         daddy yankee
# 36  latin pop,dancehall,pop,reggaeton,en espa\xc3\...           katy perry
# 37                 atlanta,trap,west coast,motown,rap              mustard
# 37                 atlanta,trap,west coast,motown,rap                migos
# 38                                    rap,r&;b,uk,pop           ed sheeran
# 39                              east coast,canada,rap            meek mill
# 40                               electro-pop,pop,r&;b               khalid
# 41  pop country,folk,musicals,screen,pop-rock,soun...            lady gaga
# 41  pop country,folk,musicals,screen,pop-rock,soun...       bradley cooper

# %%
#To remove null values, use numpy to replace the empty cells to nan
Bdf['artist'].replace('', np.nan, inplace=True)
Bdf
# Out:
#                   name_of_song peak_position weeks_on_chart  year  \
# 0                old town road           1.0            7.0  2019
# 0                old town road           1.0            7.0  2019
# 2                      bad guy           2.0           13.0  2019
# 3                         talk           3.0           20.0  2019
# 4                 i don't care           2.0            7.0  2019
# ...                        ...           ...            ...   ...
# 24995                   studio          75.0            3.0  2014
# 24996            where it's at          76.0            7.0  2014
# 24997  keep them kisses comin'          72.0            8.0  2014
# 24998             tennis court          71.0           13.0  2014
# 24999                the worst          43.0           20.0  2014
#
#                                                    genre          artist
# 0      country,atlanta,alternative country,hip-hop,tr...         lil nas
# 0      country,atlanta,alternative country,hip-hop,tr...             NaN
# 2      hip-hop,dark pop,house,trap,memes,alternative ...   billie eilish
# 3                                          synth-pop,pop          khalid
# 4                          canada,uk,dance,dance-pop,pop      ed sheeran
# ...                                                  ...             ...
# 24995                                     west coast,rap     schoolboy q
# 24996                                       rock,country    dustin lynch
# 24997                                                pop  craig campbell
# 24998  alternative pop,alternative,downtempo,new zeal...           lorde
# 24999                                               r&;b      jhene aiko
#
# [25553 rows x 6 columns]

# %%
#Checking for null values 
Bdf.isnull().sum()
# Out:
# name_of_song       0
# peak_position      0
# weeks_on_chart     0
# year               0
# genre              0
# artist            20
# dtype: int64

# %%
Bdf1 = Bdf.dropna()
Bdf1
# Out:
#                   name_of_song peak_position weeks_on_chart  year  \
# 0                old town road           1.0            7.0  2019
# 2                      bad guy           2.0           13.0  2019
# 3                         talk           3.0           20.0  2019
# 4                 i don't care           2.0            7.0  2019
# 4                 i don't care           2.0            7.0  2019
# ...                        ...           ...            ...   ...
# 24995                   studio          75.0            3.0  2014
# 24996            where it's at          76.0            7.0  2014
# 24997  keep them kisses comin'          72.0            8.0  2014
# 24998             tennis court          71.0           13.0  2014
# 24999                the worst          43.0           20.0  2014
#
#                                                    genre          artist
# 0      country,atlanta,alternative country,hip-hop,tr...         lil nas
# 2      hip-hop,dark pop,house,trap,memes,alternative ...   billie eilish
# 3                                          synth-pop,pop          khalid
# 4                          canada,uk,dance,dance-pop,pop      ed sheeran
# 4                          canada,uk,dance,dance-pop,pop   justin bieber
# ...                                                  ...             ...
# 24995                                     west coast,rap     schoolboy q
# 24996                                       rock,country    dustin lynch
# 24997                                                pop  craig campbell
# 24998  alternative pop,alternative,downtempo,new zeal...           lorde
# 24999                                               r&;b      jhene aiko
#
# [25533 rows x 6 columns]

# %%
#reseting index to remove the repeated index numbers from stacking
Bdf1.reset_index(drop=True, inplace=True)

# %%
Bdf1
# Out:
#                   name_of_song peak_position weeks_on_chart  year  \
# 0                old town road           1.0            7.0  2019
# 1                      bad guy           2.0           13.0  2019
# 2                         talk           3.0           20.0  2019
# 3                 i don't care           2.0            7.0  2019
# 4                 i don't care           2.0            7.0  2019
# ...                        ...           ...            ...   ...
# 25528                   studio          75.0            3.0  2014
# 25529            where it's at          76.0            7.0  2014
# 25530  keep them kisses comin'          72.0            8.0  2014
# 25531             tennis court          71.0           13.0  2014
# 25532                the worst          43.0           20.0  2014
#
#                                                    genre          artist
# 0      country,atlanta,alternative country,hip-hop,tr...         lil nas
# 1      hip-hop,dark pop,house,trap,memes,alternative ...   billie eilish
# 2                                          synth-pop,pop          khalid
# 3                          canada,uk,dance,dance-pop,pop      ed sheeran
# 4                          canada,uk,dance,dance-pop,pop   justin bieber
# ...                                                  ...             ...
# 25528                                     west coast,rap     schoolboy q
# 25529                                       rock,country    dustin lynch
# 25530                                                pop  craig campbell
# 25531  alternative pop,alternative,downtempo,new zeal...           lorde
# 25532                                               r&;b      jhene aiko
#
# [25533 rows x 6 columns]

# %%
#Keep only first row when there are artist/song duplicate

Bdf1.drop_duplicates(['artist', 'name_of_song'], keep='first', inplace=True)
Bdf1
# Out:
# <ipython-input-18-76c18717f894>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Bdf1.drop_duplicates(['artist', 'name_of_song'], keep='first', inplace=True)
#             name_of_song peak_position weeks_on_chart  year  \
# 0          old town road           1.0            7.0  2019
# 1                bad guy           2.0           13.0  2019
# 2                   talk           3.0           20.0  2019
# 3           i don't care           2.0            7.0  2019
# 4           i don't care           2.0            7.0  2019
# ...                  ...           ...            ...   ...
# 25458          automatic          35.0           19.0  2014
# 25459     wild wild love          30.0           18.0  2014
# 25503             demons           6.0           61.0  2014
# 25518  beat of the music          44.0           20.0  2014
# 25532          the worst          43.0           20.0  2014
#
#                                                    genre           artist
# 0      country,atlanta,alternative country,hip-hop,tr...          lil nas
# 1      hip-hop,dark pop,house,trap,memes,alternative ...    billie eilish
# 2                                          synth-pop,pop           khalid
# 3                          canada,uk,dance,dance-pop,pop       ed sheeran
# 4                          canada,uk,dance,dance-pop,pop    justin bieber
# ...                                                  ...              ...
# 25458                                       rock,country  miranda lambert
# 25459                                            pop,rap          pitbull
# 25503  adult alternative,adult contemporary,alternati...  imagine dragons
# 25518                                            country   brett eldredge
# 25532                                               r&;b       jhene aiko
#
# [1899 rows x 6 columns]

# %% [markdown]
# ### Grammy dataframe

# %%
# Rename the column headers
Gdf = Gdf.rename(columns={'Artist':'artist',
                        'GrammyAward': 'grammy_award',
                        'GrammyYear': 'grammy_year',
                        'Name': 'name_of_song',
                        'Genre': 'genre'})
Gdf
# Out:
#                                                 artist  \
# 0                                     childish gambino
# 1                                     childish gambino
# 2                                            lady gaga
# 3                           lady gaga & bradley cooper
# 4    silk city & dua lipa featuring diplo & mark ro...
# ..                                                 ...
# 423                                             eminem
# 424                    the roots featuring erykah badu
# 425                                       shania twain
# 426                                       george jones
# 427                                       shania twain
#
#                                grammy_award grammy_year  \
# 0                        record of the year        2018
# 1                          song of the year        2018
# 2                 best pop solo performance        2018
# 3            best pop duo/group performance        2018
# 4                      best dance recording        2018
# ..                                      ...         ...
# 423               best rap solo performance        1999
# 424  best rap performance by a duo or group        1999
# 425   best female country vocal performance        1999
# 426     best male country vocal performance        1999
# 427                       best country song        1999
#
#                                   name_of_song                   genre
# 0                              this is america                 general
# 1                              this is america                 general
# 2    joanne (where do you think you're goin'?)                     pop
# 3                                      shallow                     pop
# 4                                  electricity  dance/electronic music
# ..                                         ...                     ...
# 423                                 my name is                     rap
# 424                                 you got me                     rap
# 425                  man! i feel like a woman!                 country
# 426                                    choices                 country
# 427                               come on over                 country
#
# [417 rows x 5 columns]

# %%
Gdf  = Gdf .drop('artist', axis=1).join(Gdf ['artist'].str.split(',', expand=True).stack().reset_index(level=1, drop=True).rename('artist'))
Gdf
# Out:
#                                grammy_award grammy_year  \
# 0                        record of the year        2018
# 1                          song of the year        2018
# 2                 best pop solo performance        2018
# 3            best pop duo/group performance        2018
# 4                      best dance recording        2018
# ..                                      ...         ...
# 423               best rap solo performance        1999
# 424  best rap performance by a duo or group        1999
# 425   best female country vocal performance        1999
# 426     best male country vocal performance        1999
# 427                       best country song        1999
#
#                                   name_of_song                   genre  \
# 0                              this is america                 general
# 1                              this is america                 general
# 2    joanne (where do you think you're goin'?)                     pop
# 3                                      shallow                     pop
# 4                                  electricity  dance/electronic music
# ..                                         ...                     ...
# 423                                 my name is                     rap
# 424                                 you got me                     rap
# 425                  man! i feel like a woman!                 country
# 426                                    choices                 country
# 427                               come on over                 country
#
#                                                 artist
# 0                                     childish gambino
# 1                                     childish gambino
# 2                                            lady gaga
# 3                           lady gaga & bradley cooper
# 4    silk city & dua lipa featuring diplo & mark ro...
# ..                                                 ...
# 423                                             eminem
# 424                    the roots featuring erykah badu
# 425                                       shania twain
# 426                                       george jones
# 427                                       shania twain
#
# [535 rows x 5 columns]

# %%
Gdf['artist'] = Gdf['artist'].str.replace('Songwriters','')

Gdf['artist'] = Gdf['artist'].str.replace('Songwriter','')
Gdf['artist'] = Gdf['artist'].str.replace('Artists','')

Gdf['artist'] = Gdf['artist'].str.replace('Artist','')
Gdf['artist'] = Gdf['artist'].str.replace('Soloists','')
Gdf['artist'] = Gdf['artist'].str.replace('Soloist','')
Gdf['artist'] = Gdf['artist'].str.replace('(','')
Gdf['artist'] = Gdf['artist'].str.replace(')','')
Gdf['artist'] = Gdf['artist'].str.replace(u'\xa0', u'')

# %%
Gdf.isnull().sum()
# Out:
# grammy_award    0
# grammy_year     0
# name_of_song    0
# genre           0
# artist          0
# dtype: int64

# %%
#reseting index to remove the repeated index numbers from stacking
Gdf.reset_index(drop=True, inplace=True)

# %%
Gdf
# Out:
#                                grammy_award grammy_year  \
# 0                        record of the year        2018
# 1                          song of the year        2018
# 2                 best pop solo performance        2018
# 3            best pop duo/group performance        2018
# 4                      best dance recording        2018
# ..                                      ...         ...
# 530               best rap solo performance        1999
# 531  best rap performance by a duo or group        1999
# 532   best female country vocal performance        1999
# 533     best male country vocal performance        1999
# 534                       best country song        1999
#
#                                   name_of_song                   genre  \
# 0                              this is america                 general
# 1                              this is america                 general
# 2    joanne (where do you think you're goin'?)                     pop
# 3                                      shallow                     pop
# 4                                  electricity  dance/electronic music
# ..                                         ...                     ...
# 530                                 my name is                     rap
# 531                                 you got me                     rap
# 532                  man! i feel like a woman!                 country
# 533                                    choices                 country
# 534                               come on over                 country
#
#                                                 artist
# 0                                     childish gambino
# 1                                     childish gambino
# 2                                            lady gaga
# 3                           lady gaga & bradley cooper
# 4    silk city & dua lipa featuring diplo & mark ro...
# ..                                                 ...
# 530                                             eminem
# 531                     the rootsfeaturing erykah badu
# 532                                       shania twain
# 533                                       george jones
# 534                                       shania twain
#
# [535 rows x 5 columns]

# %%
import psycopg2
pw=login()
connection = None
try:
    # In PostgreSQL, default username is 'postgres' and password is 'postgres'.
    # And also there is a default database exist named as 'postgres'.
    # Default host is 'localhost' or '127.0.0.1'
    # And default port is '54322'.
    connection= psycopg2.connect(
      database='postgres', user='postgres', password=pw, host='127.0.0.1', port= '5432'
    )
    print('Database connected.')

except:
    print('Database not connected.')

if connection is not None:
    connection.autocommit = True

    cur = connection.cursor()
    cur.execute("SELECT datname FROM pg_database;")

    list_database = cur.fetchall()
    if ('musician_db',) in list_database:
        print(" Database musician_db already exist")
    else:
        print(" Database musician_db does not exist, creating one right now.......")
        sql = '''CREATE database musician_db'''
        cur.execute(sql)
        print("Database created successfully........")
    connection.close()
    print('Done')
# Out:
# Please enter your password for PGAdmin:
# Database not connected.

# %%
rds_connection_string = f"postgres:{pw}@localhost:5432/musician_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()

# %%
artist_newdf.to_sql(name='Artists', con=engine, if_exists='append', index=False)
Bill_board_newdf.to_sql(name='Billboard', con=engine, if_exists='append', index=False)
Grammy_df.to_sql(name='Grammy', con=engine, if_exists='append', index=False)
